# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\Pc\AppData\Local\Packages\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\LocalState\sessions\2AEF1D2DCD171D2153569A9A30A4F8B392E5C78A\transfers\2026-23\medical_disease_prediction_10000.csv")

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'BloodPressure', 'GlucoseLevel', 'Cholesterol',
#        'HeartRate', 'Smoking', 'Alcohol', 'PhysicalActivity', 'FamilyHistory',
#        'Disease'],
#       dtype='str')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  str
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  str
#  8   Alcohol           10000 non-null  str
#  9   PhysicalActivity  10000 non-null  str
#  10  FamilyHistory     10000 non-null  str
#  11  Disease           10000 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 937.6 KB

# %%
disease_count = df['Disease'].value_counts()
label = ['Healthy', 'Pre-Diabetes', 'Hypertension', 'Heart Disease', 'Diabetes']
plt.pie(disease_count,labels = label , autopct = "%1.1f%%")
plt.show()

# %%
sns.countplot(x='Disease', data=df , color= 'Purple')
plt.title("Distribution of Disease Cases")
plt.xlabel("Disease Status")
plt.ylabel("Number of Patients")
plt.show()

# %%
sns.countplot(data = df , x = df['Disease'],hue = df['Gender'],palette='Set1')
plt.title("Gender wise Disease Distribution")
plt.xlabel("Disease Type", fontsize=12)
plt.ylabel("Count of Patients", fontsize=12)
# Out:
# Text(0, 0.5, 'Count of Patients')

# %%
sns.countplot(x='FamilyHistory', hue='Disease', data=df, palette='Set1')
plt.title("Impact of Family History on Disease Occurrence")
plt.xlabel("Family History")
plt.ylabel("Number of Patients")
plt.show()

# %%
sns.countplot(x='Smoking', hue='Disease', data=df)
plt.title("Impact of Smoking on Disease Occurrence")
plt.xlabel("Smoking Status")
plt.ylabel("Number of Patients")
plt.show()

# %%
sns.countplot(x='Alcohol', hue='Disease', data=df)
plt.title("Impact of Alcohol Consumption on Disease Occurrence")
plt.xlabel("Alcohol Consumption")
plt.ylabel("Number of Patients")
plt.show()

# %%
sns.countplot(x='PhysicalActivity', hue='Disease', data=df)
plt.title("Impact of Physical Activity on Disease Occurrence")
plt.xlabel("Physical Activity Level")
plt.ylabel("Number of Patients")
plt.show()

# %%
sns.boxplot(x='Disease', y='Age', data=df)
plt.title("Age Distribution by Disease Status")
plt.xlabel("Disease Status")
plt.ylabel("Age")
plt.show()

# %%
sns.boxplot(x='Disease', y='BMI', data=df)
plt.title("BMI Distribution by Disease Status")
plt.xlabel("Disease Status")
plt.ylabel("BMI")
plt.show()

# %%
sns.boxplot(x='Disease', y='GlucoseLevel', data=df)
plt.title("Glucose Level Distribution by Disease Status")
plt.xlabel("Disease Status")
plt.ylabel("Glucose Level")
plt.show()

# %%
sns.boxplot(x='Disease', y='Cholesterol', data=df)
plt.title("Cholesterol Distribution by Disease Status")
plt.xlabel("Disease Status")
plt.ylabel("Cholesterol")
plt.show()

# %%
sns.boxplot(x='Disease', y='BloodPressure', data=df)
plt.title("Blood Pressure Distribution by Disease Status")
plt.xlabel("Disease Status")
plt.ylabel("Blood Pressure")
plt.show()

# %%
sns.boxplot(x='Disease', y='HeartRate', data=df)
plt.title("Heart Rate Distribution by Disease Status")
plt.xlabel("Disease Status")
plt.ylabel("Heart Rate")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
Gender_dict = {'Male':1 , 'Female':2 }
df['Gender'] = df['Gender'].map(Gender_dict)

# %%
df['Smoking'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
Smoking_dict = {'Yes' :1 , 'No':2}
df['Smoking'] = df["Smoking"].map(Smoking_dict)

# %%
df["Alcohol"].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
Alcohol_dict = {'Yes':1,'No': 2}
df['Alcohol'] = df['Alcohol'].map(Alcohol_dict)

# %%
df["PhysicalActivity"].unique()
# Out:
# <StringArray>
# ['Medium', 'High', 'Low']
# Length: 3, dtype: str

# %%
PhysicalActivity_dict = {'High':1 ,'Medium':2,'Low':3}
df['PhysicalActivity'] = df['PhysicalActivity'].map(PhysicalActivity_dict)

# %%
df["FamilyHistory"].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
Family_History_dict = {'Yes' : 1 , 'No' : 2 }
df['FamilyHistory'] = df['FamilyHistory'].map(Family_History_dict)

# %%
disease_dict = {'Healthy':1, 'Pre-Diabetes':2, 'Hypertension':3, 'Heart Disease':4, 'Diabetes':5}
df['Disease'] = df['Disease'].map(disease_dict)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  int64
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  int64
#  8   Alcohol           10000 non-null  int64
#  9   PhysicalActivity  10000 non-null  int64
#  10  FamilyHistory     10000 non-null  int64
#  11  Disease           10000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 937.6 KB

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       1  17.5            102           177          161         88
# 1      69       1  31.1            118           256          147         92
# 2      61       2  31.3            114           206          193         74
# 3      47       2  23.9            105           162          253         68
# 4      47       1  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       1  27.1            177           183          268         59
# 9996   84       1  29.2            142           215          145         77
# 9997   41       1  22.8            177           265          133         71
# 9998   55       1  29.0            126           241          298         57
# 9999   59       1  32.2            151           162          225         93
#
# ...

# %%
df.to_csv("clean_medical.csv")

# %%
x = df.drop("Disease", axis = 1)

# %%
y = df[["Disease"]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC , SVR

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42 , test_size=0.2)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((8000, 11), (2000, 11), (8000, 1), (2000, 1))

# %%
sv = SVC()
sv.fit(x_train , y_train)
# Out:
# c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
print(sv.score(x_train , y_train))
print(sv.score(x_test , y_test))
# Out:
# 0.63125
# 0.6395

# %%
from sklearn.tree import DecisionTreeClassifier , DecisionTreeRegressor
dtc = DecisionTreeClassifier()

# %%
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dtc.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(dtc.score(x_train , y_train))
print(dtc.score(x_test , y_test))
# Out:
# 1.0
# 0.6455

# %%
x_test
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 6252   36       1  23.5            122           156          146         99
# 4684   52       2  23.0            147           137          273        107
# 1731   78       1  26.3            118           128          125         55
# 4742   46       1  22.6            161           211          147         59
# 4521   64       2  27.2            126           261          162        108
# ...   ...     ...   ...            ...           ...          ...        ...
# 6412   23       2  25.5            114           204          220         99
# 8285   20       1  32.3            131           257          287         77
# 7853   53       2  26.8            180           240          306         94
# 1095   23       2  35.2            118           148          292        100
# 6929   68       2  16.5            105           117          307         62
#
# ...

# %%
y_test
# Out:
#       Disease
# 6252        1
# 4684        1
# 1731        1
# 4742        1
# 4521        3
# ...       ...
# 6412        1
# 8285        1
# 7853        3
# 1095        1
# 6929        1
#
# [2000 rows x 1 columns]

# %%
dtc.predict([[36 ,	1 , 23.5 ,	122	, 156 ,	146 , 99, 2, 	1,	2,	1]])
# Out:
# c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
y_pred = dtc.predict(x_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix

confusion_matrix(y_test , y_pred)
# Out:
# array([[1083,   92,  101,    1,    2],
#        [ 102,   70,   88,    4,    2],
#        [ 109,  104,  119,   15,    9],
#        [   9,    4,   23,    6,   11],
#        [   1,    5,   13,   14,   13]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.6455
